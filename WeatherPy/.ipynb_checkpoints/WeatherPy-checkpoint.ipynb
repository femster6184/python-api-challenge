# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/femiademuwagun/anaconda3/envs/dev/lib/python3.10/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /Users/femiademuwagun/anaconda3/envs/dev/lib/python3.10/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data =[]
unit = "metric"
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&units="+ unit +"&q=" +  city

#    Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,"Lat": city_lat,
                          "Lng": city_lng, "Max Temp": city_max_temp,
                          "Humidity": city_humidity,"Cloudiness": city_clouds,
                          "Wind Speed": city_wind,"Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodinsk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | darnah
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | xilin hot
# Processing Record 8 of Set 1 | constantia
# Processing Record 9 of Set 1 | hinton
# Processing Record 10 of Set 1 | ust-tsilma
# Processing Record 11 of Set 1 | olyokminsk
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | margaret river
# Processing Record 14 of Set 1 | isafjordur
# Processing Record 15 of Set 1 | shelbyville
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | yeniseysk
# Processing Record 18 of Set 1 | piskent
# Processing Record 19 of Set 1 | mangrol
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | stanley
# Processing Record 25 of Set 1 | ishikawa
# Processing Record 26 of Set 1 | camalu
# Processing Record 27 of Set 1 | pacasmayo
# Processing Record 28 of Set 1 | piti village
# Processing Record 29 of Set 1 | kapuskasing
# Processing Record 30 of Set 1 | burley
# Processing Record 31 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 1 | pasni
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | alabat
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | turpan
# Processing Record 38 of Set 1 | nevele
# Processing Record 39 of Set 1 | igarape miri
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | nova sintra
# Processing Record 42 of Set 1 | iskateley
# Processing Record 43 of Set 1 | cockburn town
# Processing Record 44 of Set 1 | celestun
# Processing Record 45 of Set 1 | olonkinbyen
# Processing Record 46 of Set 1 | great falls
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | hawaiian paradise park
# Processing Record 49 of Set 1 | nar'yan-mar
# Processing Record 50 of Set 1 | noumea
# Processing Record 1 of Set 2 | qarah zia' od din
# Processing Record 2 of Set 2 | santarem
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | blackmans bay
# Processing Record 5 of Set 2 | montepuez
# Processing Record 6 of Set 2 | ubari
# Processing Record 7 of Set 2 | santa rosalia
# Processing Record 8 of Set 2 | behbahan
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | howrah
# Processing Record 11 of Set 2 | wenchang
# Processing Record 12 of Set 2 | hammerfest
# Processing Record 13 of Set 2 | bardai
# Processing Record 14 of Set 2 | natal
# Processing Record 15 of Set 2 | phongsali
# Processing Record 16 of Set 2 | zhangjiajie
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | petropavlovsk-kamchatsky
# Processing Record
of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 4 | zhangye
# Processing Record 16 of Set 4 | swift current
# Processing Record 17 of Set 4 | yigo village
# Processing Record 18 of Set 4 | nahiyat ash shinafiyah
# Processing Record 19 of Set 4 | kapa'a
# Processing Record 20 of Set 4 | udachny
# Processing Record 21 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 4 | mandera
# Processing Record 23 of Set 4 | adrasmon
# Processing Record 24 of Set 4 | flying fish cove
# Processing Record 25 of Set 4 | zheleznodorozhnyy
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 28 of Set 4 | badger
# Processing Record 29 of Set 4 | hafar al-batin
# Processing Record 30 of Set 4 | rongelap
# Processing Record 31 of Set 4 | rio grande
# Processing Record 32 of Set 4 | fuyuan
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | rakops
# Processing Record 35 of Set 4 | fortaleza
# Processing Record 36 of Set 4 | whitehorse
# Processing Record 37 of Set 4 | jianshui
# Processing Record 38 of Set 4 | tacoronte
# Processing Record 39 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 4 | port douglas
# Processing Record 41 of Set 4 | bamboo flat
# Processing Record 42 of Set 4 | chinde
# Processing Record 43 of Set 4 | lospalos
# Processing Record 44 of Set 4 | pecan plantation
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | kingsburg
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | sao paulo de olivenca
# Processing Record 50 of Set 4 | ko pha ngan
# Processing Record 1 of Set 5 | whangarei
# Processing Record 2 of Set 5 | belo sur tsiribihina
# Processing Record 3 of Set 5 | inongo
# Processing Record 4 of Set 5 | spring creek
# Processing Record 5 of Set 5 | uturoa
# Processing Record 6 of Set 5 | cill airne
# Processing Record 7 of Set 5 | meads
# Processing Record 8 of Set 5 | ilulissat
# Processing Record 9 of Set 5 | bayanaul
# Processing Record 10 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 11 of Set 5 | keflavik
# Processing Record 12 of Set 5 | bikenibeu village
# Processing Record 13 of Set 5 | san angelo
# Processing Record 14 of Set 5 | azemmour
# Processing Record 15 of Set 5 | punta arenas
# Processing Record 16 of Set 5 | shaowu
# Processing Record 17 of Set 5 | kristiansund
# Processing Record 18 of Set 5 | yangcun
# Processing Record 19 of Set 5 | tolanaro
# Processing Record 20 of Set 5 | susuman
# Processing Record 21 of Set 5 | shenjiamen
# Processing Record 22 of Set 5 | gadzhiyevo
# Processing Record 23 of Set 5 | lindi
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | silvia
# Processing Record 26 of Set 5 | fisterra
# Processing Record 27 of Set 5 | brisas de zicatela
# Processing Record 28 of Set 5 | kone
# Processing Record 29 of Set 5 | bargaal
# Processing Record 30 of Set 5 | eyl
# Processing Record 31 of Set 5 | mikuni
# Processing Record 32 of Set 5 | puerto armuelles
# Processing Record 33 of Set 5 | berdigestyakh
# Processing Record 34 of Set 5 | lautoka
# Processing Record 35 of Set 5 | huicheng
# Processing Record 36 of Set 5 | kamloops
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | pasco
# Processing Record 39 of Set 5 | puerto deseado
# Processing Record 40 of Set 5 | tadine
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | howick
# Processing Record 43 of Set 5 | cranbrook
# Processing Record 44 of Set 5 | yulinshi
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | colonia
# Processing Record 47 of Set 5 | pearsall
# Processing Record 48 of Set 5 | andergrove
# Processing Record 49 of Set 5 | oranjemund
# Processing Record 50 of Set 5 | aksu
# Processing Record 1 of Set 6 | ventspils
# Processing Record 2 of Set 6 | el kala
# Processing Record 3 of Set 6 | greenville
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | tupiza
# Processing Record 6 of Set 6 | ujae
# Processing Record 7 of Set 6 | selfoss
# Processing Record 8 of Set 6 | harper
# Processing Record 9 of Set 6 | vadso
# Processing Record 10 of Set 6 | coxen hole
# Processing Record 11 of Set 6 | ust-nera
# Processing Record 12 of Set 6 | bealanana
# Processing Record 13 of Set 6 | zyryanovsk
# Processing Record 14 of Set 6 | toliara
# Processing Record 15 of Set 6 | hauterive
# Processing Record 16 of Set 6 | mount pearl
# Processing Record 17 of Set 6 | umm kaddadah
# Processing Record 18 of Set 6 | taulaga
# Processing Record 19 of Set 6 | peniche
# Processing Record 20 of Set 6 | sovetskaya gavan'
# Processing Record 21 of Set 6 | kanniyakumari
# Processing Record 22 of Set 6 | san andres
# Processing Record 23 of Set 6 | ilhabela
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | markovo
# Processing Record 26 of Set 6 | sasovo
# Processing Record 27 of Set 6 | post
# Processing Record 28 of Set 6 | nasiriyah
# Processing Record 29 of Set 6 | callao
# Processing Record 30 of Set 6 | emerald
# Processing Record 31 of Set 6 | farafangana
# Processing Record 32 of Set 6 | kenai
# Processing Record 33 of Set 6 | tamanrasset
# Processing Record 34 of Set 6 | al bahah
# Processing Record 35 of Set 6 | kingston
# Processing Record 36 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 37 of Set 6 | hithadhoo
# Processing Record 38 of Set 6 | halmstad
# Processing Record 39 of Set 6 | sao raimundo das mangabeiras
# Processing Record 40 of Set 6 | pacific grove
# Processing Record 41 of Set 6 | roznov pod radhostem
# Processing Record 42 of Set 6 | mugia
# Processing Record 43 of Set 6 | ar ruways
# Processing Record 44 of Set 6 | mil'kovo
# Processing Record 45 of Set 6 | santa ana
# Processing Record 46 of Set 6 | barra de santo antonio
# Processing Record 47 of Set 6 | juneau
# Processing Record 48 of Set 6 | tidjikja
# Processing Record 49 of Set 6 | manokwari
# Processing Record 50 of Set 6 | anantapur
# Processing Record 1 of Set 7 | minas de marcona
# Processing Record 2 of Set 7 | carutapera
# Processing Record 3 of Set 7 | qarazhal
# Processing Record 4 of Set 7 | kansanshi
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | sinabang
# Processing Record 7 of Set 7 | vorgashor
# Processing Record 8 of Set 7 | castlemaine
# Processing Record 9 of Set 7 | la foa
# Processing Record 10 of Set 7 | mae chai
# Processing Record 11 of Set 10 | luanda
# Processing Record 12 of Set 10 | damongo
# City not found. Skipping...
# Processing Record 13 of Set 10 | daru
# Processing Record 14 of Set 10 | qui nhon
# Processing Record 15 of Set 10 | fairwood
# Processing Record 16 of Set 10 | masina
# Processing Record 17 of Set 10 | yuzhno-kurilsk
# Processing Record 18 of Set 10 | glace bay
# Processing Record 19 of Set 10 | salekhard
# Processing Record 20 of Set 10 | nakasongola
# Processing Record 21 of Set 10 | phalauda
# Processing Record 22 of Set 10 | maumere
# Processing Record 23 of Set 10 | moreira sales
# Processing Record 24 of Set 10 | barah
# Processing Record 25 of Set 10 | boyolangu
# Processing Record 26 of Set 10 | jessen
# Processing Record 27 of Set 10 | papao
# Processing Record 28 of Set 10 | rahimah
# Processing Record 29 of Set 10 | puerto rico
# Processing Record 30 of Set 10 | egilsstadir
# Processing Record 31 of Set 10 | nesebar
# Processing Record 32 of Set 10 | verkhnedneprovskiy
# Processing Record 33 of Set 10 | pandan
# Processing Record 34 of Set 10 | ain defla
# Processing Record 35 of Set 10 | oriximina
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | labytnangi
# Processing Record 38 of Set 10 | howard springs
# Processing Record 39 of Set 10 | floro
# Processing Record 40 of Set 10 | ancud
# Processing Record 41 of Set 10 | baruun-urt
# Processing Record 42 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 43 of Set 10 | posto fiscal rolim de moura
# Processing Record 44 of Set 10 | kruisfontein
# Processing Record 45 of Set 10 | pieksamaki
# Processing Record 46 of Set 10 | usta muhammad
# Processing Record 47 of Set 10 | alto araguaia
# Processing Record 48 of Set 10 | ndjole
# Processing Record 49 of Set 10 | zhongshu
# Processing Record 50 of Set 10 | lexington
# Processing Record 1 of Set 11 | mount gambier
# Processing Record 2 of Set 11 | palmas
# Processing Record 3 of Set 11 | rakitnoye
# Processing Record 4 of Set 11 | folkston
# Processing Record 5 of Set 11 | belle plaine
# Processing Record 6 of Set 11 | taoudenni
# Processing Record 7 of Set 11 | kembe
# Processing Record 8 of Set 11 | atherton
# Processing Record 9 of Set 11 | grand falls-windsor
# Processing Record 10 of Set 11 | chernyshevskiy
# Processing Record 11 of Set 11 | darwin
# Processing Record 12 of Set 11 | garoua
# Processing Record 13 of Set 11 | terrace
# Processing Record 14 of Set 11 | maun
# Processing Record 15 of Set 11 | enid
# Processing Record 16 of Set 11 | huarmey
# Processing Record 17 of Set 11 | nykobing mors
# Processing Record 18 of Set 11 | phang nga
# Processing Record 19 of Set 11 | malvan
# Processing Record 20 of Set 11 | diawara
# Processing Record 21 of Set 11 | heroica caborca
# Processing Record 22 of Set 11 | roma
# Processing Record 23 of Set 11 | haiku-pauwela
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | ulanhot
# Processing Record 26 of Set 11 | priargunsk
# Processing Record 27 of Set 11 | chuguyevka
# Processing Record 28 of Set 11 | kaset sombun
# Processing Record 29 of Set 11 | torghay
# Processing Record 30 of Set 11 | smithers
# Processing Record 31 of Set 11 | tyukhtet
# Processing Record 32 of Set 11 | lupiro
# Processing Record 33 of Set 11 | lihue
# Processing Record 34 of Set 11 | kuching
# Processing Record 35 of Set 11 | rabaul
# Processing Record 36 of Set 11 | nizhniy kuranakh
# Processing Record 37 of Set 11 | ipira
# Processing Record 38 of Set 11 | mar del plata
# Processing Record 39 of Set 11 | tongchuanshi
# Processing Record 40 of Set 11 | akureyri
# Processing Record 41 of Set 11 | inari
# Processing Record 42 of Set 11 | touros
# Processing Record 43 of Set 11 | tateyama
# Processing Record 44 of Set 11 | albertina
# Processing Record 45 of Set 11 | tucumcari
# Processing Record 46 of Set 11 | aban
# Processing Record 47 of Set 11 | funafuti
# Processing Record 48 of Set 11 | ust'-kut
# Processing Record 49 of Set 11 | san sebastian de la gomera
# Processing Record 50 of Set 11 | karystos
# Processing Record 1 of Set 12 | hadibu
# Processing Record 2 of Set 12 | itacoatiara
# Processing Record 3 of Set 12 | bakanas
# Processing Record 4 of Set 12 | berezovo
# Processing Record 5 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 6 of Set 12 | thulamahashi
# Processing Record 7 of Set 12 | dul'durga
# Processing Record 8 of Set 12 | kavarna
# Processing Record 9 of Set 12 | antofagasta
# Processing Record 10 of Set 12 | mejit
# Processing Record 11 of Set 12 | broken hill
# Processing Record 12 of Set 12 | revda
# Processing Record 13 of Set 12 | queenstown
# Processing Record 14 of Set 12 | xining
# Processing Record 15 of Set 12 | sao joao da barra
# Processing Record 16 of Set 12 | kourou
# Processing Record 17 of Set 12 | novoye devyatkino
# Processing Record 18 of Set 12 | santo antonio de padua
# Processing Record 19 of Set 12 | ardestan
# Processing Record 20 of Set 12 | morant bay
# Processing Record 21 of Set 12 | timbuktu
# Processing Record 22 of Set 12 | palikir - national government center
# Processing Record 23 of Set 12 | tahe
# Processing Record 24 of Set 12 | kuvandyk
# Processing Record 25 of Set 12 | astara
# Processing Record 26 of Set 12 | aioun
# Processing Record 27 of Set 12 | guerrero negro
# Processing Record 28 of Set 12 | palu
# Processing Record 29 of Set 12 | lazaro cardenas
# Processing Record 30 of Set 12 | gemena
# Processing Record 31 of Set 12 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 32 of Set 12 | coron
# Processing Record 33 of Set 12 | singkawang
# Processing Record 34 of Set 12 | san cristobal
# Processing Record 35 of Set 12 | taza
# Processing Record 36 of Set 12 | chulym
# Processing Record 37 of Set 12 | shangmei
# Processing Record 38 of Set 12 | isla vista
# Processing Record 39 of Set 12 | suva
# Processing Record 40 of Set 12 | likiep
# Processing Record 41 of Set 12 | pailon
# Processing Record 42 of Set 12 | kununurra
# Processing Record 43 of Set 12 | olenino
# Processing Record 44 of Set 12 | gallup
# Processing Record 45 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 46 of Set 12 | arvayheer
# Processing Record 47 of Set 12 | praia
# Processing Record 48 of Set 12 | medina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#view city data
print(city_data)
# Out:
# [{'City': 'kodinsk', 'Lat': 58.6881, 'Lng': 99.1844, 'Max Temp': 18.74, 'Humidity': 65, 'Cloudiness': 94, 'Wind Speed': 1.39, 'Country': 'RU', 'Date': 1691715688}, {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 0.81, 'Humidity': 100, 'Cloudiness': 75, 'Wind Speed': 3.09, 'Country': 'AR', 'Date': 1691715688}, {'City': 'port-aux-francais', 'Lat': -49.35, 'Lng': 70.2167, 
, 'Cloudiness': 0, 'Wind Speed': 1.73, 'Country': 'UZ', 'Date': 1691715690}, {'City': 'mangrol', 'Lat': 21.1167, 'Lng': 70.1167, 'Max Temp': 26.68, 'Humidity': 82, 'Cloudiness': 100, 'Wind Speed': 6.66, 'Country': 'IN', 'Date': 1691715690}, {'City': 'qaqortoq', 'Lat': 60.7167, 'Lng': -46.0333, 'Max Temp': 6.67, 'Humidity': 78, 'Cloudiness': 100, 'Wind Speed': 0.56, 'Country': 'GL', 'Date': 1691715690}, {'City': 'grytviken', 'Lat': -54.2811, 'Lng': -36.5092, 'Max Temp': -0.23, 'Humidity': 98, 'Cloudiness': 100, 'Wind Speed': 5.23, 'Country': 'GS', 'Date': 1691715690}, {'City': 'puerto natales', 'Lat': -51.7236, 'Lng': -72.4875, 'Max Temp': -0.47, 'Humidity': 94, 'Cloudiness': 17, 'Wind Speed': 1.9, 'Country': 'CL', 'Date': 1691715690}, {'City': 'west island', 'Lat': -12.1568, 'Lng': 96.8225, 'Max Temp': 24.99, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 5.66, 'Country': 'CC', 'Date': 1691715691}, {'City': 'stanley', 'Lat': 54.868, 'Lng': -1.6985, 'Max Temp': 18.83, 'Humidity': 86, 'Cloudiness': 0, 'Wind Speed': 2.06, 'Country': 'GB', 'Date': 1691715691}, {'City': 'ishikawa', 'Lat':  ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0            kodinsk  58.6881  99.1844     18.74        65          94
# 1            ushuaia -54.8000 -68.3000      0.81       100          75
# 2  port-aux-francais -49.3500  70.2167      3.42        78          53
# 3             bethel  41.3712 -73.4140     21.47        86         100
# 4             darnah  32.7670  22.6367     25.06        67           0
#
#    Wind Speed Country        Date
# 0        1.39      RU  1691715688
# 1        3.09      AR  1691715688
# 2       16.32      TF  1691715688
# 3        1.24      US  1691715688
# 4        7.85      LY  1691715688

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  kodinsk  58.6881  99.1844     18.74        65          94
# 1                  ushuaia -54.8000 -68.3000      0.81       100          75
# 2        port-aux-francais -49.3500  70.2167      3.42        78          53
# 3                   bethel  41.3712 -73.4140     21.47        86         100
# 4                   darnah  32.7670  22.6367     25.06        67           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.39      RU  1691715688
# 1              3.09      AR  1691715688
# 2             16.32      TF  1691715688
# 3              1.24      US  1691715688
# 4              7.85      LY  1691715688

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Max Temp"]
plt.scatter(x_axis, y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Humidity"]
plt.scatter(x_axis, y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Cloudiness"]
plt.scatter(x_axis, y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Wind Speed"]
plt.scatter(x_axis, y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
    regress_values=slope*x_values+intercept
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    line_eq="y = " + str(round(slope,3)) + "x +" + str(round(intercept,3))
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           kodinsk  58.6881   99.1844     18.74        65          94
# 3            bethel  41.3712  -73.4140     21.47        86         100
# 4            darnah  32.7670   22.6367     25.06        67           0
# 6         xilin hot  43.9667  116.0333     24.16        70          91
# 7        constantia  44.1833   28.6500     20.39        59          95
#
#          Wind Speed Country        Date
# City_ID
# 0              1.39      RU  1691715688
# 3              1.24      US  1691715688
# 4              7.85      LY  1691715688
# 6              1.97      CN  1691715514
# 7              6.15      RO  1691715399

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                  ushuaia -54.8000  -68.3000      0.81       100          75
# 2        port-aux-francais -49.3500   70.2167      3.42        78          53
# 5                 waitangi -43.9535 -176.5597     12.68        90         100
# 11               adamstown -25.0660 -130.1015     17.96        61          14
# 12          margaret river -33.9500  115.0667     13.71        70          23
#
#          Wind Speed Country        Date
# City_ID
# 1              3.09      AR  1691715688
# 2             16.32      TF  1691715688
# 5              2.68      NZ  1691715688
# 11            10.53      PN  1691715689
# 12             2.17      AU  1691715689

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Max Temp"]
plt.ylabel("Max Temperature(C)")
plot_linear_regression(x_values, y_values,"Max Temp", (43,40))
# Out:
# The r-squared is: 0.4252783759200079

# %%
# Linear regression on Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Max Temp"]
plt.ylabel("Max Temperature(C)")
plot_linear_regression(x_values, y_values,"Max Temp", (-50,35))
# Out:
# The r-squared is: 0.6970965227267689

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive correlation(Positive slope) between the Latitude and Maximum temperature in the Southern Hemisphere compared to a negative association(negative slope) in the Northern Hemisphere. In other words, as you move away from the equator, the temperature tends to decrease. It seems like temperatures are typically warmer approaching the equator and cooler towards the poles.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Humidity"]
plt.ylabel("Humidity(%)")
plot_linear_regression(x_values, y_values, "Humidity", (44,12))
# Out:
# The r-squared is: 0.00017147716392174636

# %%
# Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Humidity"]
plt.ylabel("Humidity(%)")
plot_linear_regression(x_values, y_values, "Humidity", (-50,17))
# Out:
# The r-squared is: 0.0014351966988823464

# %% [markdown]
# **Discussion about the linear relationship:** From the data for both hemisphere, it seems like there is no or very minimal correlation between Latitude and humidity (r-squared is very close to 0).

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Cloudiness"]
plt.ylabel("Cloudiness(%)")
plot_linear_regression(x_values, y_values, "Cloudiness", (43,35))
# Out:
# The r-squared is: 0.0002749601254461626

# %%
# Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Cloudiness"]
plt.ylabel("Cloudiness(%)")
plot_linear_regression(x_values, y_values, "Cloudiness", (-57,13))
# Out:
# The r-squared is: 1.9750188669175817e-06

# %% [markdown]
# **Discussion about the linear relationship:** No correlation between Latitude and cloudiness for both the northern and southern hemisphere as seen from the r-square value of about 0.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Wind Speed"]
plt.ylabel("Wind Speed(m/s)")
plot_linear_regression(x_values, y_values, "Wind Speed", (30,11))
# Out:
# The r-squared is: 0.0010103869109384218

# %%
# Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Wind Speed"]
plt.ylabel("Wind Speed(m/s)")
plot_linear_regression(x_values, y_values, "Wind Speed", (-55,14))
# Out:
# The r-squared is: 0.02000151643547651

# %% [markdown]
# **Discussion about the linear relationship:** No correlation between Latitude and wind speed for both the northern and southern hemisphere as seen from the r-square value of about 0.
