# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat      Lng  Max Temp  Humidity  \
# 0        0            kodinsk  58.6881  99.1844     18.74        65
# 1        1            ushuaia -54.8000 -68.3000      0.81       100
# 2        2  port-aux-francais -49.3500  70.2167      3.42        78
# 3        3             bethel  41.3712 -73.4140     21.47        86
# 4        4             darnah  32.7670  22.6367     25.06        67
#
#    Cloudiness  Wind Speed Country        Date
# 0          94        1.39      RU  1691715688
# 1          75        3.09      AR  1691715688
# 2          53       16.32      TF  1691715688
# 3         100        1.24      US  1691715688
# 4           0        7.85      LY  1691715688

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot=city_data_df.hvplot.points("Lng","Lat", geo=True, tiles="OSM", frame_width=800, frame_height=500, size="Humidity",scale=0.5, color="City")

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city_data_df=city_data_df.loc[(city_data_df["Max Temp"]<28) & (city_data_df["Max Temp"]>21) & (city_data_df["Humidity"]<75)& (city_data_df["Wind Speed"]<5) & (city_data_df["Cloudiness"]==0)]

# Drop any rows with null values
ideal_city_data_df.dropna()

# Display sample data
ideal_city_data_df
# Out:
#      City_ID                          City      Lat       Lng  Max Temp  \
# 17        17                       piskent  40.8972   69.3506     24.04
# 54        54                         ubari  26.5921   12.7805     26.39
# 145      145                       pachino  36.7186   15.0907     23.93
# 218      218                          kone -21.0595  164.8658     23.30
# 223      223                 berdigestyakh  62.0989  126.6992     22.23
# 238      238                    andergrove -21.0833  149.1833     24.80
# 270      270                       emerald -23.5333  148.1667     22.41
# 273      273                   tamanrasset  22.7850    5.5228     24.95
# 278      278  sao raimundo das mangabeiras  -7.0219  -45.4811     25.57
# 333      333                       yeppoon -23.1333  150.7333     22.88
# 346      346                      misratah  32.3754   15.0925     24.97
# 354      354                   villamontes -21.2500  -63.5000     22.66
# 402      402                     araguaina  -7.1911  -48.2072     26.16
# 411      411                         inonu  37.3167   33.7667     21.75
# 426      426                     aragarcas -15.8975  -52.2508     25.60
# 455      455                 moreira sales -24.0622  -53.0069     21.60
# 478      478                 alto araguaia -17.3147  -53.2153     22.65
# 483      483                        palmas -10.2128  -48.3603     26.93
# 549      549                      ardestan  33.3761   52.3694     25.51
# 573      573                        gallup  35.5281 -108.7426     26.42
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 17         34           0        1.73      UZ  1691715690
# 54         29           0        3.51      LY  1691715693
# 145        62           0        1.87      IT  1691715703
# 218        38           0        3.89      NC  1691715715
# 223        54           0        3.70      RU  1691715716
# 238        55           0        3.61      AU  1691715719
# 270        50           0        1.21      AU  1691715725
# 273        11           0        3.09      DZ  1691715726
# 278        39           0        1.55      BR  1691715727
# 333        55           0        2.59      AU  1691715735
# 346        63           0        1.88      LY  1691715736
# 354        39           0        1.77      BO  1691715737
# 402        35           0        1.76      BR  1691715690
# 411        48           0        0.71      TR  1691715742
# 426        36           0        1.35      BR  1691715744
# 455        48           0        3.83      BR  1691715663
# 478        34           0        2.23      BR  1691715752
# 483        50           0        2.06      BR  1691715542
# 549        19           0        1.79      IR  1691715760
# 573        50           0        2.57      US  1691715764

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=ideal_city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.insert(5,"Hotel Name","")

# Display sample data
hotel_df
# Out:
#                              City Country      Lat       Lng  Humidity  \
# 17                        piskent      UZ  40.8972   69.3506        34
# 25                         camalu      MX  30.8500 -116.0667        75
# 54                          ubari      LY  26.5921   12.7805        29
# 83                  alice springs      AU -23.7000  133.8833        26
# 145                       pachino      IT  36.7186   15.0907        62
# 166                      adrasmon      TJ  40.6472   69.9856        35
# 218                          kone      NC -21.0595  164.8658        38
# 223                 berdigestyakh      RU  62.0989  126.6992        54
# 238                    andergrove      AU -21.0833  149.1833        55
# 270                       emerald      AU -23.5333  148.1667        50
# 273                   tamanrasset      DZ  22.7850    5.5228        11
# 278  sao raimundo das mangabeiras      BR  -7.0219  -45.4811        39
# 333                       yeppoon      AU -23.1333  150.7333        55
# 346                      misratah      LY  32.3754   15.0925        63
# 354                   villamontes      BO -21.2500  -63.5000        39
# 402                     araguaina      BR  -7.1911  -48.2072        35
# 411                         inonu      TR  37.3167   33.7667        48
# 426                     aragarcas      BR -15.8975  -52.2508        36
# 455                 moreira sales      BR -24.0622  -53.0069        48
# 478                 alto araguaia      BR -17.3147  -53.2153        34
# 483                        palmas      BR -10.2128  -48.3603        50
# 549                      ardestan      IR  33.3761   52.3694        19
# 566                      shangmei      CN  27.7428  111.2956        75
# 573                        gallup      US  35.5281 -108.7426        50
#
#     Hotel Name
# 17
# 25
# 54
# 83
# 145
# 166
# 218
# 223
# 238
# 270
# 273
# 278
# 333
# 346
# 354
# 402
# 411
# 426
# 455
# 478
# 483
# 549
# 566
# 573

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key, "limit": 20
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    
    longitude = row["Lng"]
    #print(longitude)
    latitude = row ["Lat"]
    #print(latitude)
    
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# piskent - nearest hotel: Brez
# camalu - nearest hotel: Margaritaville
# ubari - nearest hotel: فندق اوباري
# alice springs - nearest hotel: Aurora Alice Springs
# pachino - nearest hotel: Hotel Celeste
# adrasmon - nearest hotel: No hotel found
# kone - nearest hotel: Pacifik Appartels
# berdigestyakh - nearest hotel: No hotel found
# andergrove - nearest hotel: No hotel found
# emerald - nearest hotel: Emerald Central Hotel
# tamanrasset - nearest hotel: فندق الأمان
# sao raimundo das mangabeiras - nearest hotel: No hotel found
# yeppoon - nearest hotel: Blossom's on Seaspray
# misratah - nearest hotel: الفندق السياحى
# villamontes - nearest hotel: Hoterma
# araguaina - nearest hotel: No hotel found
# inonu - nearest hotel: No hotel found
# aragarcas - nearest hotel: Hotel Portal da Praia
# moreira sales - nearest hotel: No hotel found
# alto araguaia - nearest hotel: Hotel Araguaia
# palmas - nearest hotel: Hotel Triângulo Mineiro
# ardestan - nearest hotel: Tourism Hotel
# shangmei - nearest hotel: No hotel found
# gallup - nearest hotel: No hotel found
#                              City Country      Lat       Lng  Humidity  \
# 17                        piskent      UZ  40.8972   69.3506        34
# 25                         camalu      MX  30.8500 -116.0667        75
# 54                          ubari      LY  26.5921   12.7805        29
# 83                  alice springs      AU -23.7000  133.8833        26
# 145                       pachino      IT  36.7186   15.0907        62
# 166                      adrasmon      TJ  40.6472   69.9856        35
# 218                          kone      NC -21.0595  164.8658        38
# 223                 berdigestyakh      RU  62.0989  126.6992        54
# 238                    andergrove      AU -21.0833  149.1833        55
# 270                       emerald      AU -23.5333  148.1667        50
# 273                   tamanrasset      DZ  22.7850    5.5228        11
# 278  sao raimundo das mangabeiras      BR  -7.0219  -45.4811        39
# 333                       yeppoon      AU -23.1333  150.7333        55
# 346                      misratah      LY  32.3754   15.0925        63
# 354                   villamontes      BO -21.2500  -63.5000        39
# 402                     araguaina      BR  -7.1911  -48.2072        35
# 411                         inonu      TR  37.3167   33.7667        48
# 426                     aragarcas      BR -15.8975  -52.2508        36
# 455                 moreira sales      BR -24.0622  -53.0069        48
# 478                 alto araguaia      BR -17.3147  -53.2153        34
# 483                        palmas      BR -10.2128  -48.3603        50
# 549                      ardestan      IR  33.3761   52.3694        19
# 566                      shangmei      CN  27.7428  111.2956        75
# 573                        gallup      US  35.5281 -108.7426        50
#
#                   Hotel Name
# 17                      Brez
# 25            Margaritaville
# 54               فندق اوباري
# 83      Aurora Alice Springs
# 145            Hotel Celeste
# 166           No hotel found
# 218        Pacifik Appartels
# 223           No hotel found
# 238           No hotel found
# 270    Emerald Central Hotel
# 273              فندق الأمان
# 278           No hotel found
# 333    Blossom's on Seaspray
# 346           الفندق السياحى
# 354                  Hoterma
# 402           No hotel found
# 411           No hotel found
# 426    Hotel Portal da Praia
# 455           No hotel found
# 478           Hotel Araguaia
# 483  Hotel Triângulo Mineiro
# 549            Tourism Hotel
# 566           No hotel found
# 573           No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot2=hotel_df.hvplot.points("Lng","Lat", hover_cols=["Country","Hotel Name"], geo=True, tiles="OSM", frame_width=800, frame_height=500, size="Humidity",scale=0.5, color="City")

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
